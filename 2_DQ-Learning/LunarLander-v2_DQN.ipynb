# %%
import gym
import os

import matplotlib.pyplot as plt
import numpy as np
import torch as T
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim


# Double Deep Q 
class DQN(nn.Module):
    def __init__(self,learning_rate,input_dims,fc1_dims,fc2_dims,num_actions):
        super(DQN,self).__init__()
        
        print("input dimensions: ",input_dims[0],"number of actions: ",num_actions)
        
        # Three fully connected layers
        self.fc1 = nn.Linear(*input_dims,fc1_dims) # * unpacks the list of input_dims since it's 2-dimensional (same as input_dims[0])
        self.fc2 = nn.Linear(fc1_dims,fc2_dims)
        self.fc3 = nn.Linear(fc2_dims,num_actions)
        
        self.optimizer = optim.Adam(self.parameters(),lr=learning_rate)
        self.loss = nn.MSELoss()
        
        # Set device
        self.device = T.device('cuda:0' if T.cuda.is_available() else 'cpu:0')
        self.to(self.device)
        
    def forward(self,state):
        x = F.relu(self.fc1(state))
        x = F.relu(self.fc2(x))
        x = self.fc3(x)
        
        return x
    
# Agent 
class Agent:
    def __init__(self,discount,epsilon,learning_rate,input_dims,batch_size,num_actions,mem_size=500000,min_epsilon=0.05,epsilon_decay=0.0005):
        # Brain of the agent
        self.DQN = DQN(learning_rate,input_dims,256,256,num_actions)
        self.DQN_next = DQN(learning_rate,input_dims,256,256,num_actions)
        self.DQN_next.load_state_dict(self.DQN.state_dict()) # loads a model's parameter dictionary using a deserialized state_dict
        
        # Hyper-parameters
        self.discount = discount
        self.epsilon = epsilon
        self.min_epsilon = min_epsilon
        self.epsilon_decay = epsilon_decay
        self.learning_rate = learning_rate
        self.action_space = [i for i in range(num_actions)]
        self.mem_size = mem_size
        self.batch_size = batch_size
        self.mem_counter = 0
        
        # Initialize memory 
        self.state_mem = np.zeros((mem_size,*input_dims),dtype=np.float32) # mem_size number of dim[0]*dim[1] matrices of zeros
        self.new_state_mem = np.zeros((mem_size,*input_dims),dtype=np.float32)
        self.action_mem = np.zeros(mem_size,dtype=np.int32)
        self.reward_mem = np.zeros(mem_size,dtype=np.float32)
        self.terminal_mem = np.zeros(mem_size,dtype=bool) # boolean value indicating whether it's the last memory
        
    # Store records inside the memory
    def storage(self,state,new_state,action,reward,terminal):
        index = self.mem_counter%self.mem_size # equal to mem_counter if mem_counter < mem_size
        self.state_mem[index] = state
        self.new_state_mem[index] = new_state
        self.reward_mem[index] = reward
        self.action_mem[index] = action
        self.terminal_mem[index] = terminal
        
        self.mem_counter += 1
        
    # Take actions
    def get_action(self,observation):
        if np.random.random() < self.epsilon:
            # Randomly choose one action from the action space
            action = np.random.choice(self.action_space)
        else:
            state = T.tensor([observation]).to(self.DQN.device)
            actions = self.DQN(state.float()) # same as self.to(torch.float32)
            action = T.argmax(actions).item() # the action corresponding to the index of the maximizing action in the actions tensor
        return action
    
    # Learning
    def learn(self):
        # Check memory counter against batch size since the latter comes from the former
        if self.mem_counter < self.batch_size:
            return
        
        # Initialize gradients
        self.DQN.optimizer.zero_grad()
        
        # Generate batch such that the batch size is smaller than the number of results in the memory
        max_batch = min(self.mem_counter,self.mem_size)
        batch = np.random.choice(max_batch,self.batch_size,replace=False)
        batch_index = np.arange(self.batch_size,dtype=np.int32)
        
        state_batch = T.tensor(self.state_mem[batch]).to(self.DQN.device)
        new_state_batch = T.tensor(self.new_state_mem[batch]).to(self.DQN.device)
        reward_batch = T.tensor(self.reward_mem[batch]).to(self.DQN.device)
        terminal_batch = T.tensor(self.terminal_mem[batch]).to(self.DQN.device)
        action_batch = self.action_mem[batch] # cannot follow the above format since used as index
        
        q_next = self.DQN_next(new_state_batch)
        q_eval = self.DQN(state_batch)[batch_index,action_batch]
        
        q_target = reward_batch+self.discount*T.max(q_next,dim=1)[0]
        q_target[terminal_batch] = 0.0
        
        # Backprop 
        loss = self.DQN.loss(q_target,q_eval).to(self.DQN.device)
        loss.backward() # get the gradient of the current tensor
        self.DQN.optimizer.step()
        self.update_epsilon()
        
    # Epsilon decay
    def update_epsilon(self):
        if self.epsilon > self.min_epsilon:
            self.epsilon = self.epsilon-self.epsilon_decay
    
    def update_network(self):
        self.DQN_next.load_state_dict(self.DQN.state_dict())      

        
# Model training
if __name__=='__main__':
    env = gym.make("LunarLander-v2")
    input_dims = [env.observation_space.shape[0]]
    num_actions = env.action_space.n
    discount = 0.99
    epsilon = 1.0
    learning_rate = 0.001
    batch_size = 64
    
    agent = Agent(discount,epsilon,learning_rate,input_dims,batch_size,num_actions)
    
    scores = []
    avg_scores = []
    episodes = 500
    learn = True
    
    for i in range(episodes):
        score = 0
        state = env.reset()
        done = False
        
        while not done:
            action = agent.get_action(state)
            new_state,reward,done,info = env.step(action)
            
            if i%10 == 0:
                env.render()
            
            score += reward
            
            agent.storage(state,new_state,action,reward,done)
            if learn:
                agent.learn()
                # Update target every 5 episodes
                if i%5 == 0  and i != 0:
                    agent.update_network()
                    
            state = new_state
            
        scores.append(score)
        avg_score = np.mean(scores[-50:])
        avg_scores.append(avg_score)
        print("Episode: ",i,"\tScore: ",score,"\tAverage Score: %.3f"% avg_score,"Epsilon %.3f" % agent.epsilon)
        
        # Early stopping when average score of the last 10 episodes is above 200
        if np.mean(scores[-50:]) > 200:
            episodes = i+1
            break
    
    checkpoint = {"model":agent.DQN.state_dict(),"score":scores,"episodes":episodes} 
    #save_dir = "C:/Users/Yang Yue/OneDrive/Documents/GitHub/STAT_430/prep/"
    save_dir = "/Users/Yang/OneDrive/Documents/GitHub/STAT_430/prep/"
    T.save(checkpoint,save_dir+"lunarlander-DQN.pt")
    
    x = [i+1 for i in range(episodes)]
    plt.plot(x,scores,label="episode_reward")
    plt.plot(x,avg_scores,label="average_reward")
    plt.xlabel("Episode")
    plt.ylabel("Reward")
    plt.title("Learning Curve DQN")
    plt.legend()
    plt.show()
# Out:
# input dimensions:  8 number of actions:  4
# input dimensions:  8 number of actions:  4
# Episode:  0 	Score:  -137.98686311096904 	Average Score: -137.987 Epsilon 0.995
# Episode:  1 	Score:  -141.45321724574495 	Average Score: -139.720 Epsilon 0.946
# Episode:  2 	Score:  -290.2892315040786 	Average Score: -189.910 Epsilon 0.903
# Episode:  3 	Score:  -303.2712013308415 	Average Score: -218.250 Epsilon 0.851
# Episode:  4 	Score:  -7.611573040492914 	Average Score: -176.122 Epsilon 0.790
# Episode:  5 	Score:  -85.15329504250161 	Average Score: -160.961 Epsilon 0.752
# Episode:  6 	Score:  -107.13210430685153 	Average Score: -153.271 Epsilon 0.705
# Episode:  7 	Score:  -118.01465314678956 	Average Score: -148.864 Epsilon 0.649
# Episode:  8 	Score:  -242.85642363036158 	Average Score: -159.308 Epsilon 0.597
# Episode:  9 	Score:  -22.41407467839103 	Average Score: -145.618 Epsilon 0.554
# Episode:  10 	Score:  -310.7414523157023 	Average Score: -160.629 Epsilon 0.461
# Episode:  11 	Score:  -160.17857322991358 	Average Score: -160.592 Epsilon 0.385
# Episode:  12 	Score:  -63.19013402552301 	Average Score: -153.099 Epsilon 0.261
# Episode:  13 	Score:  -89.9744832400788 	Average Score: -148.591 Epsilon 0.050
# Episode:  14 	Score:  -247.7851483573683 	Average Score: -155.203 Epsilon 0.050
# Episode:  15 	Score:  -222.6653249825682 	Average Score: -159.420 Epsilon 0.050
# Episode:  16 	Score:  -103.58765544408251 	Average Score: -156.136 Epsilon 0.050
# Episode:  17 	Score:  -31.92974486867358 	Average Score: -149.235 Epsilon 0.050
# Episode:  18 	Score:  -445.6434589048252 	Average Score: -164.836 Epsilon 0.050
# Episode:  19 	Score:  -145.57156326125653 	Average Score: -163.873 Epsilon 0.050
# Episode:  20 	Score:  -137.3315232730267 	Average Score: -162.609 Epsilon 0.050
# Episode:  21 	Score:  -24.682161386511638 	Average Score: -156.339 Epsilon 0.050
# Episode:  22 	Score:  -100.23750517919498 	Average Score: -153.900 Epsilon 0.050
# Episode:  23 	Score:  -32.383321156186724 	Average Score: -148.837 Epsilon 0.050
# Episode:  24 	Score:  -31.211675751681213 	Average Score: -144.132 Epsilon 0.050
# Episode:  25 	Score:  -20.97092933550673 	Average Score: -139.395 Epsilon 0.050
# Episode:  26 	Score:  227.7028820924903 	Average Score: -125.799 Epsilon 0.050
# Episode:  27 	Score:  -142.55380723073057 	Average Score: -126.397 Epsilon 0.050
# Episode:  28 	Score:  -1.7681702521287264 	Average Score: -122.100 Epsilon 0.050
# Episode:  29 	Score:  14.876816566746925 	Average Score: -117.534 Epsilon 0.050
# Episode:  30 	Score:  199.07702566493595 	Average Score: -107.320 Epsilon 0.050
# Episode:  31 	Score:  9.687079944289277 	Average Score: -103.664 Epsilon 0.050
# Episode:  32 	Score:  -62.74158338664478 	Average Score: -102.424 Epsilon 0.050
# Episode:  33 	Score:  89.91386085977751 	Average Score: -96.767 Epsilon 0.050
# Episode:  34 	Score:  -60.84179836514286 	Average Score: -95.740 Epsilon 0.050
# Episode:  35 	Score:  -21.377527183480012 	Average Score: -93.675 Epsilon 0.050
# Episode:  36 	Score:  -36.72906507370473 	Average Score: -92.136 Epsilon 0.050
# Episode:  37 	Score:  -27.354911146862843 	Average Score: -90.431 Epsilon 0.050
# Episode:  38 	Score:  176.16693765837758 	Average Score: -83.595 Epsilon 0.050
# Episode:  39 	Score:  -21.988904007501272 	Average Score: -82.055 Epsilon 0.050
# Episode:  40 	Score:  -18.43724082946739 	Average Score: -80.503 Epsilon 0.050
# Episode:  41 	Score:  144.95432977979576 	Average Score: -75.135 Epsilon 0.050
# Episode:  42 	Score:  171.90850226810397 	Average Score: -69.390 Epsilon 0.050
# Episode:  43 	Score:  152.43364479995216 	Average Score: -64.349 Epsilon 0.050
# Episode:  44 	Score:  -34.18405526550613 	Average Score: -63.678 Epsilon 0.050
# Episode:  45 	Score:  72.80129904557921 	Average Score: -60.711 Epsilon 0.050
# Episode:  46 	Score:  -0.22259178856817297 	Average Score: -59.424 Epsilon 0.050
# Episode:  47 	Score:  206.23036579310272 	Average Score: -53.890 Epsilon 0.050
# Episode:  48 	Score:  -6.311532159742157 	Average Score: -52.919 Epsilon 0.050
# Episode:  49 	Score:  0.001367304447494 	Average Score: -51.860 Epsilon 0.050
# Episode:  50 	Score:  19.798428332299746 	Average Score: -48.705 Epsilon 0.050
# Episode:  51 	Score:  248.14030682282086 	Average Score: -40.913 Epsilon 0.050
# Episode:  52 	Score:  273.10118179890696 	Average Score: -29.645 Epsilon 0.050
# Episode:  53 	Score:  254.20088522703747 	Average Score: -18.496 Epsilon 0.050
# Episode:  54 	Score:  144.93629089049065 	Average Score: -15.445 Epsilon 0.050
# Episode:  55 	Score:  243.34946103004438 	Average Score: -8.875 Epsilon 0.050
# Episode:  56 	Score:  263.4763628043477 	Average Score: -1.462 Epsilon 0.050
# Episode:  57 	Score:  259.8008597980595 	Average Score: 6.094 Epsilon 0.050
# Episode:  58 	Score:  -34.534913745358104 	Average Score: 10.260 Epsilon 0.050
# Episode:  59 	Score:  161.83332394515105 	Average Score: 13.945 Epsilon 0.050
# Episode:  60 	Score:  -9.678124326479534 	Average Score: 19.966 Epsilon 0.050
# Episode:  61 	Score:  56.90837940370386 	Average Score: 24.308 Epsilon 0.050
# Episode:  62 	Score:  200.50021678302804 	Average Score: 29.582 Epsilon 0.050
# Episode:  63 	Score:  259.9350051051566 	Average Score: 36.580 Epsilon 0.050
# Episode:  64 	Score:  215.90076512781448 	Average Score: 45.854 Epsilon 0.050
# Episode:  65 	Score:  19.21193192271457 	Average Score: 50.691 Epsilon 0.050
# Episode:  66 	Score:  231.27045878301436 	Average Score: 57.389 Epsilon 0.050
# Episode:  67 	Score:  123.13037475213414 	Average Score: 60.490 Epsilon 0.050
# Episode:  68 	Score:  263.1021794442282 	Average Score: 74.665 Epsilon 0.050
# Episode:  69 	Score:  264.67087402781425 	Average Score: 82.870 Epsilon 0.050
# Episode:  70 	Score:  241.5744839873308 	Average Score: 90.448 Epsilon 0.050
# Episode:  71 	Score:  249.34470900506722 	Average Score: 95.928 Epsilon 0.050
# Episode:  72 	Score:  223.98528358071349 	Average Score: 102.413 Epsilon 0.050
# Episode:  73 	Score:  55.5574501710629 	Average Score: 104.172 Epsilon 0.050
# Episode:  74 	Score:  195.73362150193157 	Average Score: 108.710 Epsilon 0.050
# Episode:  75 	Score:  303.55471253055185 	Average Score: 115.201 Epsilon 0.050
# Episode:  76 	Score:  80.10032623723978 	Average Score: 112.249 Epsilon 0.050
# Episode:  77 	Score:  235.35028154784482 	Average Score: 119.807 Epsilon 0.050
# Episode:  78 	Score:  -11.256501037448428 	Average Score: 119.617 Epsilon 0.050
# Episode:  79 	Score:  254.10171189505476 	Average Score: 124.402 Epsilon 0.050
# Episode:  80 	Score:  258.2720448294336 	Average Score: 125.586 Epsilon 0.050
# Episode:  81 	Score:  -100.2828918297502 	Average Score: 123.386 Epsilon 0.050
# Episode:  82 	Score:  105.14737018100111 	Average Score: 126.744 Epsilon 0.050
# Episode:  83 	Score:  147.65844765923703 	Average Score: 127.899 Epsilon 0.050
# Episode:  84 	Score:  214.31656860426318 	Average Score: 133.402 Epsilon 0.050
# Episode:  85 	Score:  229.24501867732843 	Average Score: 138.415 Epsilon 0.050
# Episode:  86 	Score:  266.17735767415365 	Average Score: 144.473 Epsilon 0.050
# Episode:  87 	Score:  208.71859390725336 	Average Score: 149.194 Epsilon 0.050
# Episode:  88 	Score:  262.8772441050771 	Average Score: 150.928 Epsilon 0.050
# Episode:  89 	Score:  258.8742251193778 	Average Score: 156.546 Epsilon 0.050
# Episode:  90 	Score:  146.43434347269007 	Average Score: 159.843 Epsilon 0.050
# Episode:  91 	Score:  226.91397684150928 	Average Score: 161.482 Epsilon 0.050
# Episode:  92 	Score:  18.953669519372156 	Average Score: 158.423 Epsilon 0.050
# Episode:  93 	Score:  116.04656023640226 	Average Score: 157.695 Epsilon 0.050
# Episode:  94 	Score:  245.21532319507395 	Average Score: 163.283 Epsilon 0.050
# Episode:  95 	Score:  248.4628824644659 	Average Score: 166.797 Epsilon 0.050
# Episode:  96 	Score:  -87.88695083214556 	Average Score: 165.043 Epsilon 0.050
# Episode:  97 	Score:  266.22074568493315 	Average Score: 166.243 Epsilon 0.050
# Episode:  98 	Score:  -132.41987381545832 	Average Score: 163.721 Epsilon 0.050
# Episode:  99 	Score:  -219.09181162552983 	Average Score: 159.339 Epsilon 0.050
# Episode:  100 	Score:  -117.79937016999776 	Average Score: 156.587 Epsilon 0.050
# Episode:  101 	Score:  -355.81624370083097 	Average Score: 144.508 Epsilon 0.050
# Episode:  102 	Score:  72.41094380921943 	Average Score: 140.494 Epsilon 0.050
# Episode:  103 	Score:  -179.1235897991059 	Average Score: 131.828 Epsilon 0.050
# Episode:  104 	Score:  -48.79754060505535 	Average Score: 127.953 Epsilon 0.050
# Episode:  105 	Score:  -36.66894839296771 	Average Score: 122.353 Epsilon 0.050
# Episode:  106 	Score:  230.52650777496046 	Average Score: 121.694 Epsilon 0.050
# Episode:  107 	Score:  234.66852872208452 	Average Score: 121.191 Epsilon 0.050
# Episode:  108 	Score:  274.0925686571692 	Average Score: 127.364 Epsilon 0.050
# Episode:  109 	Score:  243.88923330877827 	Average Score: 129.005 Epsilon 0.050
# Episode:  110 	Score:  138.10740244251664 	Average Score: 131.960 Epsilon 0.050
# Episode:  111 	Score:  232.52485231275665 	Average Score: 135.473 Epsilon 0.050
# Episode:  112 	Score:  173.63817696030839 	Average Score: 134.935 Epsilon 0.050
# Episode:  113 	Score:  -19.09075429464542 	Average Score: 129.355 Epsilon 0.050
# Episode:  114 	Score:  -52.88048981611229 	Average Score: 123.979 Epsilon 0.050
# Episode:  115 	Score:  11.427745178440375 	Average Score: 123.824 Epsilon 0.050
# Episode:  116 	Score:  69.43495739628912 	Average Score: 120.587 Epsilon 0.050
# Episode:  117 	Score:  242.3229866543562 	Average Score: 122.971 Epsilon 0.050
# Episode:  118 	Score:  267.1356386235267 	Average Score: 123.051 Epsilon 0.050
# Episode:  119 	Score:  150.61846222158542 	Average Score: 120.770 Epsilon 0.050
# Episode:  120 	Score:  223.42035424954818 	Average Score: 120.407 Epsilon 0.050
# Episode:  121 	Score:  276.9545979680068 	Average Score: 120.960 Epsilon 0.050
# Episode:  122 	Score:  13.103357628113386 	Average Score: 116.742 Epsilon 0.050
# Episode:  123 	Score:  225.47145908641815 	Average Score: 120.140 Epsilon 0.050
# Episode:  124 	Score:  114.94782800588206 	Average Score: 118.524 Epsilon 0.050
# Episode:  125 	Score:  69.17962425060782 	Average Score: 113.837 Epsilon 0.050
# Episode:  126 	Score:  -74.90416777239744 	Average Score: 110.737 Epsilon 0.050
# Episode:  127 	Score:  262.8631555425417 	Average Score: 111.287 Epsilon 0.050
# Episode:  128 	Score:  142.67330396389082 	Average Score: 114.366 Epsilon 0.050
# Episode:  129 	Score:  240.26076984018184 	Average Score: 114.089 Epsilon 0.050
# Episode:  130 	Score:  226.5919950823381 	Average Score: 113.455 Epsilon 0.050
# Episode:  131 	Score:  242.73461897711397 	Average Score: 120.316 Epsilon 0.050
# Episode:  132 	Score:  191.51076970934514 	Average Score: 122.043 Epsilon 0.050
# Episode:  133 	Score:  228.12846239813786 	Average Score: 123.652 Epsilon 0.050
# Episode:  134 	Score:  -111.90097449684723 	Average Score: 117.128 Epsilon 0.050
# Episode:  135 	Score:  229.75806474553252 	Average Score: 117.138 Epsilon 0.050
# Episode:  136 	Score:  244.43363774708442 	Average Score: 116.703 Epsilon 0.050
# Episode:  137 	Score:  -14.420260711686666 	Average Score: 112.241 Epsilon 0.050
# Episode:  138 	Score:  3.3674392881497823 	Average Score: 107.050 Epsilon 0.050
# Episode:  139 	Score:  264.23083402277575 	Average Score: 107.157 Epsilon 0.050
# Episode:  140 	Score:  278.4625262211739 	Average Score: 109.798 Epsilon 0.050
# Episode:  141 	Score:  -59.10167222695112 	Average Score: 104.078 Epsilon 0.050
# Episode:  142 	Score:  15.155589483272948 	Average Score: 104.002 Epsilon 0.050
# Episode:  143 	Score:  258.60099598507145 	Average Score: 106.853 Epsilon 0.050
# Episode:  144 	Score:  267.80858985286415 	Average Score: 107.305 Epsilon 0.050
# Episode:  145 	Score:  30.09382702992871 	Average Score: 102.937 Epsilon 0.050
# Episode:  146 	Score:  62.138761979083995 	Average Score: 105.938 Epsilon 0.050
# Episode:  147 	Score:  272.91397290430433 	Average Score: 106.072 Epsilon 0.050
# Episode:  148 	Score:  75.77035269554565 	Average Score: 110.236 Epsilon 0.050
# Episode:  149 	Score:  10.052634626336683 	Average Score: 114.818 Epsilon 0.050
# Episode:  150 	Score:  -318.46365977082553 	Average Score: 110.805 Epsilon 0.050
# Episode:  151 	Score:  277.3880846575559 	Average Score: 123.469 Epsilon 0.050
# Episode:  152 	Score:  5.233630682290837 	Average Score: 122.126 Epsilon 0.050
# Episode:  153 	Score:  -45.38860904364273 	Average Score: 124.800 Epsilon 0.050
# Episode:  154 	Score:  -18.13467364358337 	Average Score: 125.414 Epsilon 0.050
# Episode:  155 	Score:  -111.94192829866249 	Average Score: 123.908 Epsilon 0.050
# Episode:  156 	Score:  -4.393877071814003 	Average Score: 119.210 Epsilon 0.050
# Episode:  157 	Score:  278.45415007906104 	Average Score: 120.085 Epsilon 0.050
# Episode:  158 	Score:  -115.75200238374642 	Average Score: 112.289 Epsilon 0.050
# Episode:  159 	Score:  254.0789662773845 	Average Score: 112.492 Epsilon 0.050
# Episode:  160 	Score:  255.55821266823244 	Average Score: 114.841 Epsilon 0.050
# Episode:  161 	Score:  213.32737937248334 	Average Score: 114.457 Epsilon 0.050
# Episode:  162 	Score:  225.16183845804733 	Average Score: 115.488 Epsilon 0.050
# Episode:  163 	Score:  265.99762011790585 	Average Score: 121.190 Epsilon 0.050
# Episode:  164 	Score:  205.49543741973895 	Average Score: 126.357 Epsilon 0.050
# Episode:  165 	Score:  285.2423379056642 	Average Score: 131.834 Epsilon 0.050
# Episode:  166 	Score:  -3.1529629402465247 	Average Score: 130.382 Epsilon 0.050
# Episode:  167 	Score:  68.85005054745021 	Average Score: 126.912 Epsilon 0.050
# Episode:  168 	Score:  247.7043229729951 	Average Score: 126.524 Epsilon 0.050
# Episode:  169 	Score:  -248.01459277110942 	Average Score: 118.551 Epsilon 0.050
# Episode:  170 	Score:  257.39686306342026 	Average Score: 119.231 Epsilon 0.050
# Episode:  171 	Score:  277.5692466275441 	Average Score: 119.243 Epsilon 0.050
# Episode:  172 	Score:  247.4205960160001 	Average Score: 123.929 Epsilon 0.050
# Episode:  173 	Score:  263.88527659655847 	Average Score: 124.697 Epsilon 0.050
# Episode:  174 	Score:  296.97073919150847 	Average Score: 128.338 Epsilon 0.050
# Episode:  175 	Score:  224.99736626741299 	Average Score: 131.454 Epsilon 0.050
# Episode:  176 	Score:  133.9327681174497 	Average Score: 135.631 Epsilon 0.050
# Episode:  177 	Score:  247.9805596004333 	Average Score: 135.333 Epsilon 0.050
# Episode:  178 	Score:  237.17879649026167 	Average Score: 137.223 Epsilon 0.050
# Episode:  179 	Score:  223.1498871971782 	Average Score: 136.881 Epsilon 0.050
# Episode:  180 	Score:  223.79923620571537 	Average Score: 136.825 Epsilon 0.050
# Episode:  181 	Score:  219.53294977696453 	Average Score: 136.361 Epsilon 0.050
# Episode:  182 	Score:  -81.81419363061407 	Average Score: 130.895 Epsilon 0.050
# Episode:  183 	Score:  40.03071169830352 	Average Score: 127.133 Epsilon 0.050
# Episode:  184 	Score:  -42.95209154305019 	Average Score: 128.512 Epsilon 0.050
# Episode:  185 	Score:  225.9268787508234 	Average Score: 128.435 Epsilon 0.050
# Episode:  186 	Score:  262.27086551386617 	Average Score: 128.792 Epsilon 0.050
# Episode:  187 	Score:  256.7798521617116 	Average Score: 134.216 Epsilon 0.050
# Episode:  188 	Score:  160.84701277237062 	Average Score: 137.366 Epsilon 0.050
# Episode:  189 	Score:  250.89342265680926 	Average Score: 137.099 Epsilon 0.050
# Episode:  190 	Score:  219.74753242339835 	Average Score: 135.925 Epsilon 0.050
# Episode:  191 	Score:  166.2816393495033 	Average Score: 140.432 Epsilon 0.050
# Episode:  192 	Score:  290.49399958440165 	Average Score: 145.939 Epsilon 0.050
# Episode:  193 	Score:  -65.23388195008786 	Average Score: 139.462 Epsilon 0.050
# Episode:  194 	Score:  0.27238863421800286 	Average Score: 134.112 Epsilon 0.050
# Episode:  195 	Score:  232.45904692375086 	Average Score: 138.159 Epsilon 0.050
# Episode:  196 	Score:  268.92973497009484 	Average Score: 142.295 Epsilon 0.050
# Episode:  197 	Score:  137.54886867830314 	Average Score: 139.587 Epsilon 0.050
# Episode:  198 	Score:  272.38806574027547 	Average Score: 143.520 Epsilon 0.050
# Episode:  199 	Score:  226.60664500621857 	Average Score: 147.851 Epsilon 0.050
# Episode:  200 	Score:  259.63989096850725 	Average Score: 159.413 Epsilon 0.050
# Episode:  201 	Score:  213.5286670245573 	Average Score: 158.136 Epsilon 0.050
# Episode:  202 	Score:  264.83115189354646 	Average Score: 163.328 Epsilon 0.050
# Episode:  203 	Score:  299.13575325858915 	Average Score: 170.218 Epsilon 0.050
# Episode:  204 	Score:  299.1788437361673 	Average Score: 176.564 Epsilon 0.050
# Episode:  205 	Score:  274.95988670323845 	Average Score: 184.302 Epsilon 0.050
# Episode:  206 	Score:  -300.9726455004675 	Average Score: 178.371 Epsilon 0.050
# Episode:  207 	Score:  -3.7609492040597843 	Average Score: 172.727 Epsilon 0.050
# Episode:  208 	Score:  290.17777072016327 	Average Score: 180.845 Epsilon 0.050
# Episode:  209 	Score:  -21.69313041360502 	Average Score: 175.330 Epsilon 0.050
# Episode:  210 	Score:  -14.550473879717615 	Average Score: 169.928 Epsilon 0.050
# Episode:  211 	Score:  140.18620956029332 	Average Score: 168.465 Epsilon 0.050
# Episode:  212 	Score:  296.3849895495275 	Average Score: 169.889 Epsilon 0.050
# Episode:  213 	Score:  269.58489093954677 	Average Score: 169.961 Epsilon 0.050
# Episode:  214 	Score:  31.76438394253492 	Average Score: 166.486 Epsilon 0.050
# Episode:  215 	Score:  35.86357255536009 	Average Score: 161.499 Epsilon 0.050
# Episode:  216 	Score:  296.90061210959163 	Average Score: 167.500 Epsilon 0.050
# Episode:  217 	Score:  178.67808470549264 	Average Score: 169.696 Epsilon 0.050
# Episode:  218 	Score:  269.4645895413329 	Average Score: 170.132 Epsilon 0.050
# Episode:  219 	Score:  153.30209923094864 	Average Score: 178.158 Epsilon 0.050
# Episode:  220 	Score:  22.51269738732914 	Average Score: 173.460 Epsilon 0.050
# Episode:  221 	Score:  264.91421650869927 	Average Score: 173.207 Epsilon 0.050
# Episode:  222 	Score:  261.2361600503946 	Average Score: 173.483 Epsilon 0.050
# Episode:  223 	Score:  255.6762813434144 	Average Score: 173.319 Epsilon 0.050
# Episode:  224 	Score:  240.53688392645742 	Average Score: 172.191 Epsilon 0.050
# Episode:  225 	Score:  221.16071215791848 	Average Score: 172.114 Epsilon 0.050
# Episode:  226 	Score:  281.49930407476444 	Average Score: 175.065 Epsilon 0.050
# Episode:  227 	Score:  43.68972329979135 	Average Score: 170.979 Epsilon 0.050
# Episode:  228 	Score:  257.68801413518685 	Average Score: 171.390 Epsilon 0.050
# Episode:  229 	Score:  244.7759541759912 	Average Score: 171.822 Epsilon 0.050
# Episode:  230 	Score:  29.67581551172816 	Average Score: 167.940 Epsilon 0.050
# Episode:  231 	Score:  258.41499913154166 	Average Score: 168.717 Epsilon 0.050
# Episode:  232 	Score:  261.72809165427174 	Average Score: 175.588 Epsilon 0.050
# Episode:  233 	Score:  288.90859095030396 	Average Score: 180.566 Epsilon 0.050
# Episode:  234 	Score:  242.208228431171 	Average Score: 186.269 Epsilon 0.050
# Episode:  235 	Score:  307.6847951750374 	Average Score: 187.904 Epsilon 0.050
# Episode:  236 	Score:  274.62251638702696 	Average Score: 188.151 Epsilon 0.050
# Episode:  237 	Score:  -10.256428634898086 	Average Score: 182.810 Epsilon 0.050
# Episode:  238 	Score:  -35.10411394492877 	Average Score: 178.891 Epsilon 0.050
# Episode:  239 	Score:  211.59903494468386 	Average Score: 178.105 Epsilon 0.050
# Episode:  240 	Score:  -31.494733195096387 	Average Score: 173.081 Epsilon 0.050
# Episode:  241 	Score:  143.531999236866 	Average Score: 172.626 Epsilon 0.050
# Episode:  242 	Score:  -270.52599848346097 	Average Score: 161.405 Epsilon 0.050
# Episode:  243 	Score:  287.1989582006467 	Average Score: 168.454 Epsilon 0.050
# Episode:  244 	Score:  267.8866073914935 	Average Score: 173.806 Epsilon 0.050
# Episode:  245 	Score:  292.65264711257385 	Average Score: 175.010 Epsilon 0.050
# Episode:  246 	Score:  261.29634550928625 	Average Score: 174.857 Epsilon 0.050
# Episode:  247 	Score:  257.2938341872662 	Average Score: 177.252 Epsilon 0.050
# Episode:  248 	Score:  278.6784194583317 	Average Score: 177.378 Epsilon 0.050
# Episode:  249 	Score:  216.85940935131617 	Average Score: 177.183 Epsilon 0.050
# Episode:  250 	Score:  249.27671168421202 	Average Score: 176.976 Epsilon 0.050
# Episode:  251 	Score:  217.58720532094904 	Average Score: 177.057 Epsilon 0.050
# Episode:  252 	Score:  -107.33142025336947 	Average Score: 169.614 Epsilon 0.050
# Episode:  253 	Score:  261.1837674808528 	Average Score: 168.855 Epsilon 0.050
# Episode:  254 	Score:  258.6218183420696 	Average Score: 168.044 Epsilon 0.050
# Episode:  255 	Score:  159.4370683969293 	Average Score: 165.733 Epsilon 0.050
# Episode:  256 	Score:  276.3408441105157 	Average Score: 177.279 Epsilon 0.050
# Episode:  257 	Score:  272.370051197875 	Average Score: 182.802 Epsilon 0.050
# Episode:  258 	Score:  266.6547139111626 	Average Score: 182.332 Epsilon 0.050
# Episode:  259 	Score:  245.80935170685646 	Average Score: 187.682 Epsilon 0.050
# Episode:  260 	Score:  247.1160629346437 	Average Score: 192.915 Epsilon 0.050
# Episode:  261 	Score:  255.491327227103 	Average Score: 195.221 Epsilon 0.050
# Episode:  262 	Score:  -21.05403075543073 	Average Score: 188.872 Epsilon 0.050
# Episode:  263 	Score:  259.0718812687014 	Average Score: 188.662 Epsilon 0.050
# Episode:  264 	Score:  229.68776848656663 	Average Score: 192.620 Epsilon 0.050
# Episode:  265 	Score:  233.89838030111721 	Average Score: 196.581 Epsilon 0.050
# Episode:  266 	Score:  127.54696058970532 	Average Score: 193.194 Epsilon 0.050
# Episode:  267 	Score:  214.38641753321963 	Average Score: 193.908 Epsilon 0.050
# Episode:  268 	Score:  215.21285364056268 	Average Score: 192.823 Epsilon 0.050
# Episode:  269 	Score:  263.8357712466691 	Average Score: 195.034 Epsilon 0.050
# Episode:  270 	Score:  225.72837054026078 	Average Score: 199.098 Epsilon 0.050
# Episode:  271 	Score:  236.59784786072112 	Average Score: 198.532 Epsilon 0.050
# Episode:  272 	Score:  267.27985294886173 	Average Score: 198.653 Epsilon 0.050
# Episode:  273 	Score:  262.2542153229949 	Average Score: 198.784 Epsilon 0.050
# Episode:  274 	Score:  250.004822850658 	Average Score: 198.974 Epsilon 0.050
# Episode:  275 	Score:  271.1582970720723 	Average Score: 199.974 Epsilon 0.050
# Episode:  276 	Score:  216.61598631144892 	Average Score: 198.676 Epsilon 0.050
# Episode:  277 	Score:  259.82722089755345 	Average Score: 202.999 Epsilon 0.050
